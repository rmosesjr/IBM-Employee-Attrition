# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.formula.api as sm
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', None)

df = pd.read_excel("IBM Employee Attrition.xlsx")

# %%
df.head(3)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2  Female
# 1          1  Life Sciences               2                        3    Male
# 2          2          Other               4                        4    Male
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0               3         2        Sales Executive                4
# 1               2         2     Research Scientist                2
# 2               2         1  Laboratory Technician                3
#
# ...

# %%
df["Attrition"].replace(["No","Yes"],[0,1],inplace = True)

# %%
df.head(3)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   41          1      Travel_Rarely                   Sales
# 1   49          0  Travel_Frequently  Research & Development
# 2   37          1      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                        2  Female               3         2
# 1                        3    Male               2         2
# 2                        4    Male               2         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# ...

# %%
#(df.corr()).loc[]
# Out:
#   Cell In[5], line 1
#     (df.corr()).loc[]
#                     ^
# SyntaxError: invalid syntax

# %%
mod1 = sm.logit('(Attrition) ~ Age + C(BusinessTravel) + DistanceFromHome + C(EnvironmentSatisfaction) + C(Gender) + C(JobInvolvement) + C(JobRole) + C(JobSatisfaction) +  C(MaritalStatus) +  MonthlyIncome  + NumCompaniesWorked + C(OverTime) + PercentSalaryHike + C(PerformanceRating) +  C(RelationshipSatisfaction) + C(StockOptionLevel) + TotalWorkingYears + TrainingTimesLastYear + (WorkLifeBalance) + YearsAtCompany +  YearsInCurrentRole +  YearsSinceLastPromotion + YearsWithCurrManager', data=df).fit()

mod1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.287275
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1427
# Method:                           MLE   Df Model:                           42
# Date:                Mon, 14 Aug 2023   Pseudo R-squ.:                  0.3496
# Time:                        11:20:19   Log-Likelihood:                -422.29
# converged:                       True   LL-Null:                       -649.29
# Covariance Type:            nonrobust   LLR p-value:                 1.551e-70
# ...
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
    mod1 = sm.logit(f"(Attrition) ~  (BusinessTravel) + C(EnvironmentSatisfaction) + C(JobInvolvement) + C(JobLevel) + C(JobSatisfaction) + C(OverTime) + C(StockOptionLevel) + C(RelationshipSatisfaction) + C(WorkLifeBalance) + YearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager", data=df).fit()
    print(mod1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.315114
#          Iterations 8
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1441
# Method:                           MLE   Df Model:                           28
# Date:                Mon, 14 Aug 2023   Pseudo R-squ.:                  0.2866
# Time:                        11:56:42   Log-Likelihood:                -463.22
# converged:                       True   LL-Null:                       -649.29
# Covariance Type:            nonrobust   LLR p-value:                 8.549e-62
# ...
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...
